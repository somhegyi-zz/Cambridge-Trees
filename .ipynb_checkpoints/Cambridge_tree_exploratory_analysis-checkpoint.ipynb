# %% [markdown]
# # Exploratory analysis of trees in Cambridge, MA

# %% [markdown]
# To get a little more practice wrangling and exploring data, I decided to play with a lovely dataset provided by the City of Cambridge. Here is a study of all the trees and tree planting sites owned, planted, or maintained by the City of Cambridge, the Massachusetts Department of Conservation and Recreation, MIT, Harvard University and other private organizations.
#
# Data downloaded Dec 20, 2017 from: https://data.cambridgema.gov/Public-Works/Street-Trees/ni4i-5bnn and https://www.cambridgema.gov/GIS/gisdatadictionary/Environmental/ENVIRONMENTAL_StreetTrees

# %%
#Various imports
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import urllib

from bokeh.io import output_file, output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, LogColorMapper, BasicTicker, ColorBar,
    DataRange1d, PanTool, WheelZoomTool, BoxSelectTool, CategoricalColorMapper)
from bokeh.models.mappers import ColorMapper, LinearColorMapper

# %matplotlib inline 
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Get data

# %%
# %cd /Users/hannah/git/Cambridge_Tree_Viz
# Data from: https://www.cambridgema.gov/GIS/gisdatadictionary/Environmental/ENVIRONMENTAL_StreetTrees

df = pd.read_csv('ENVIRONMENTAL_StreetTrees.csv')
df.head()
# Out:
# /Users/hannah/git/Cambridge_Tree_Viz
# /Users/hannah/anaconda/envs/py35/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (29,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             the_geom  \
# 0  {type=Point, coordinates=List(-71.116314320322...
# 1  {type=Point, coordinates=List(-71.116463606176...
# 2  {type=Point, coordinates=List(-71.117121295780...
# 3  {type=Point, coordinates=List(-71.117457233419...
# 4  {type=Point, coordinates=List(-71.117663150576...
#
#                        modified  trunks                       created  \
# 0  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 1  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 2  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# ...

# %% [markdown]
# # Exploratory analyses

# %% [markdown]
# Ask some basic questions while also getting a sense for how the data quality looks. Will be cleaning things up as I go along.

# %% [markdown]
# ## What site type is the majority of the entries?

# %% [markdown]
# From data [source's site:](https://www.cambridgema.gov/GIS/gisdatadictionary/Environmental/ENVIRONMENTAL_StreetTrees)
#
# __SiteType__
# Designates whether the site is currently occupied by a tree (Tree) or stump (Stump), is an empty planting site (Planting Site), or has been paved over or is otherwise empty and no longer available for planting (Retired).
#
# _Note: this field typically supersedes any conflicting data within the record; for example, a record designated as a “Planting Site” would indicate that any values for Diameter and Trunks were no longer valid._

# %%
# number of entries
print("Number of rows:", len(df))

# Check that there are no nan values
print('Null values present:', df.SiteType.isnull().any())

# Count number of null values
count_nan = len(df.SiteType) - df.SiteType.count()
print('Num null values:', count_nan)
# Out:
# Number of rows: 31481
# Null values present: True
# Num null values: 89

# %%
# Remove rows that do not have a site type
df = df[df['SiteType'].notnull()]

# Lets look at the distribution of site types
df['SiteType'].value_counts()
# Out:
# Tree             29334
# Retired            926
# Stump              574
# Planting Site      484
# Proposed Tree       74
# Name: SiteType, dtype: int64

# %%
# Lets look at the distribution of site types
ax = df['SiteType'].value_counts().plot(kind='bar')
plt.xticks(rotation='horizontal')
plt.ylabel('Frequency')
plt.title('Distribution of tree site types')

# %% [markdown]
# The majority of the sites are trees. There is a small proportion of trees that are retired, stump or empty planting site. It would be interesting to see where these are in Cambridge. For example, do certain neighborhoods (eg sites of major construction) have more empty planting sites than others?

# %% [markdown]
# ### Where are the different site types located?

# %%
# First I need to get the x and y coordinates of each tree (currently stored as a string)

# Get all positions
all_positions_list = df.the_geom.tolist()

# Initialize lists for x and y values
x_value_list = []
y_value_list = []

for i in all_positions_list:
    # A typical value will look something like this:
    # '{type=Point, coordinates=List(-71.11631432032273, 42.38359430732255)}'
    
    start = i.find('(')
    end = i.find(')')
    
    range_of_xy = i[start+1:end]
    
    comma = range_of_xy.find(',')
    space = range_of_xy.find(' ')
    
    # Get x and y
    x = range_of_xy[0:comma]
    y = range_of_xy[space+1:]
    
    # Add these values to list
    x_value_list.append(x)
    y_value_list.append(y)
    
df['longitude'] = x_value_list
df['latitude'] = y_value_list

df.head()
# Out:
#                                             the_geom  \
# 0  {type=Point, coordinates=List(-71.116314320322...
# 1  {type=Point, coordinates=List(-71.116463606176...
# 2  {type=Point, coordinates=List(-71.117121295780...
# 3  {type=Point, coordinates=List(-71.117457233419...
# 4  {type=Point, coordinates=List(-71.117663150576...
#
#                        modified  trunks                       created  \
# 0  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 1  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 2  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 3  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 4  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
#
#   SiteType                     PlantDate                    RemovalDat  \
# 0     Tree  11/30/1899 12:00:00 AM +0000  11/30/1899 12:00:00 AM +0000
# 1     Tree  05/31/2012 12:00:00 AM +0000  11/30/1899 12:00:00 AM +0000
# ...

# %%
# modified from: http://www.bigendiandata.com/2017-06-27-Mapping_in_Jupyter/
# Plot location of sites

map_options = GMapOptions(lat = 42.374, lng = -71.114, map_type = 'roadmap', zoom = 13)

p = gmap("AIzaSyC97uvC8gah54eShvRpvxg7JDlRM4vR9m0", map_options, title='Location of sites by type')

source = ColumnDataSource(
        data = dict(
        lat = df.latitude.tolist(),
        lon = df.longitude.tolist(),
        tree_type = df.SiteType.tolist()
    )
)

color_mapper = CategoricalColorMapper(factors=['Tree',
                                               'Retired',
                                               'Stump',
                                               'Planting Site',
                                               'Proposed Tree'],
                                      palette=['#1f77b4',
                                               '#ff7f0e',
                                               '#2ca02c',
                                               '#d62728',
                                               '#9467bd'])

p.circle(x = 'lon',
         y = 'lat',
#          size = 5,
         fill_color = {'field': 'tree_type', 'transform': color_mapper},
         fill_alpha = 0.4,
         source = source,
         legend = 'tree_type',
         line_color = None)

p.legend.location = 'top_right'
p.legend.click_policy ='hide'
p.axis.visible = False

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="84c0bd58-ffb8-48a9-84cc-3c63d24a4f6b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# # Plotting with plotly
# import plotly.plotly as py

# data = [ dict(
#         type = 'scattergeo',
#         locationmode = 'USA-states',
#         lat = Retired_df['latitude'],
#         lon = Retired_df['longitude'],
#         text = Retired_df['SpeciesSho'],
#         mode = 'markers',
#         marker = dict(
#             size = 8,
#             opacity = 0.5,
#             reversescale = True,
#             autocolorscale = False,
#             symbol = 'circle',
#             line = dict(
#                 width=1,
#                 color='rgba(102, 102, 102)'
#             ),
# #             colorscale = scl,
#             cmin = 0,
#             color = Retired_df['SiteType'],
#             cmax = len(set(Retired_df['SiteType'])),
#             colorbar=dict(
#                 title="Site type"
#             )
#         ))]

# layout = dict(
#         title = 'Trees in Cambridge, MA<br>(Hover for species)',
#         colorbar = True,
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),
#             showland = True,
#             landcolor = "rgb(250, 250, 250)",
#             subunitcolor = "rgb(217, 217, 217)",
#             countrycolor = "rgb(217, 217, 217)",
#             countrywidth = 0.5,
#             subunitwidth = 0.5
#         ),
#     )

# fig = dict( data=data, layout=layout )
# py.iplot( fig, validate=False, filename='cambridge_trees' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hsomhegyi/658.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## When were trees planted?

# %%
# Convert to datetime object
cambridge_tree_df['PlantDate'] = pd.to_datetime(cambridge_tree_df['PlantDate'],infer_datetime_format=True)
cambridge_tree_df['plant_year'] = pd.DatetimeIndex(cambridge_tree_df['PlantDate']).year
cambridge_tree_df['plant_month'] = pd.DatetimeIndex(cambridge_tree_df['PlantDate']).month
cambridge_tree_df.head()
# Out:
#                                             the_geom  \
# 0  {type=Point, coordinates=List(-71.116314320322...
# 1  {type=Point, coordinates=List(-71.116463606176...
# 2  {type=Point, coordinates=List(-71.117121295780...
# 3  {type=Point, coordinates=List(-71.117457233419...
# 4  {type=Point, coordinates=List(-71.117663150576...
#
#                        modified  trunks                       created  \
# 0  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 1  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 2  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 3  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 4  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
#
#   SiteType  PlantDate                    RemovalDat   SpeciesSho TreeCondit  \
# 0     Tree 1899-11-30  11/30/1899 12:00:00 AM +0000       Linden       Good
# ...

# %%
# Plot what year trees were planted

# Find min and max years
min_plant_year = cambridge_tree_df['plant_year'].min()
max_plant_year = cambridge_tree_df['plant_year'].max()

years = np.arange(min_plant_year, max_plant_year + 1)
g = sns.factorplot(x="plant_year", data=cambridge_tree_df, kind="count", size=6, aspect=1.5, order=years)
g.set_xticklabels(step=10)
plt.xlabel('Year planted')
plt.ylabel('Number of trees')

# %% [markdown]
# Apparently most trees were planted in 1899. That arbitrary number suggests that the plant date for many of the trees is unknown and instead is listed as 1899.

# %%
# Here are all the years that we have for when trees were planted in Cambridge
years_trees_planted = sorted(list(cambridge_tree_df.plant_year.unique()))
years_trees_planted
# Out:
# [1899,
#  1970,
#  1980,
#  1985,
#  1990,
#  2000,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %% [markdown]
# Seems like we have good data for 2005 and on, so lets look at trees planted from 2005 and on.

# %%
years = np.arange(2005, max_plant_year + 1)
g = sns.factorplot(x="plant_year", data=cambridge_tree_df, kind="count", size=6, aspect=1.5, order=years)
g.set_xticklabels(step=1)
plt.xlabel('Year planted')
plt.ylabel('Number of trees')

# %% [markdown]
# ### What months of the year are trees typically planted?

# %%
# Lets first take trees that were planted between 2005 and 2017
planting_years = np.arange(2005, 2018)

cambridge_tree_plant_years_df = cambridge_tree_df.loc[cambridge_tree_df['plant_year'].isin(planting_years)]
cambridge_tree_plant_years_df.shape
# Out:
# (4227, 54)

# %%
g = sns.factorplot(x="plant_month", data=cambridge_tree_plant_years_df, kind="count", size=6, aspect=1.5)
g.set_xticklabels(step=1)
plt.xlabel('month planted')
plt.ylabel('Number of trees')

# %% [markdown]
# See two peaks of tree planting periods - spring and fall. Perhaps trees planted in the spring are a different kind than those planted in the fall?

# %%
# Lets plot this as a radial plot
print('total number of trees planted:', cambridge_tree_plant_years_df.plant_month.count())
cambridge_tree_plant_years_df.plant_month.value_counts()
# Out:
# total number of trees planted: 4227
# 11    1125
# 5      980
# 6      817
# 10     772
# 7      218
# 4      130
# 9       81
# 8       64
# 12      36
# 1        3
# 2        1
# Name: plant_month, dtype: int64

# %%
num_trees_planted_per_month = [3, 1, 0, 130, 980, 817, 218, 64, 81, 772, 1125, 36]

# divide by total num of trees planted to get proportions
prop_trees_planted_per_month = [x / 4227 for x in num_trees_planted_per_month]

# %%
from math import pi
 
# Num of values (12 for months in year)
categories = ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
N = len(categories)

values = prop_trees_planted_per_month
values += values[:1]
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0.1,0.2,0.3], ["10%","20%","30%"], color="grey", size=7)
plt.ylim(0,0.3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'g', alpha=0.1)
plt.title('Month of tree planting')

# %% [markdown]
# ## How about when trees are being removed?

# %%
# Convert to datetime object
cambridge_tree_df['RemovalDat'] = pd.to_datetime(cambridge_tree_df['RemovalDat'],infer_datetime_format=True)
cambridge_tree_df['Removal_year'] = pd.DatetimeIndex(cambridge_tree_df['RemovalDat']).year
cambridge_tree_df['Removal_month'] = pd.DatetimeIndex(cambridge_tree_df['RemovalDat']).month
cambridge_tree_df.head()
# Out:
#                                             the_geom  \
# 0  {type=Point, coordinates=List(-71.116314320322...
# 1  {type=Point, coordinates=List(-71.116463606176...
# 2  {type=Point, coordinates=List(-71.117121295780...
# 3  {type=Point, coordinates=List(-71.117457233419...
# 4  {type=Point, coordinates=List(-71.117663150576...
#
#                        modified  trunks                       created  \
# 0  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 1  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 2  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 3  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 4  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
#
#   SiteType  PlantDate RemovalDat   SpeciesSho TreeCondit  OverheadWi  \
# 0     Tree 1899-11-30 1899-11-30       Linden       Good           0
# 1     Tree 2012-05-31 1899-11-30        Maple       Fair           1
# ...

# %%
years = np.arange(1899, 2018)
g = sns.factorplot(x="Removal_year", data=cambridge_tree_df, kind="count", size=6, aspect=1.5, order=years)
g.set_xticklabels(step=10)
plt.xlabel('Year removed')
plt.ylabel('Number of trees')

# %% [markdown]
# Seems like there is a problem with the data. Every tree has a removal date?! Let's get rid of those that have 1899 removal dates as those are probably wrong.

# %%
# Here are all the years that we have for when trees were removed in Cambridge
years_trees_removed = sorted(list(cambridge_tree_df.Removal_year.unique()))
years_trees_removed
# Out:
# [1899, 1970, 2006, 2008, 2009, 2010, 2011, 2012, 2013, 2015, 2016]

# %%
years = np.arange(2005, 2018)
g = sns.factorplot(x="Removal_year", data=cambridge_tree_df, kind="count", size=6, aspect=1.5, order=years)
g.set_xticklabels(step=1)
plt.xlabel('Year removed')
plt.ylabel('Number of trees')

# %% [markdown]
# ### Now, lets look at month of removals

# %%
# Lets first take trees that were removed between 2005 and 2017
removal_years = np.arange(2005, 2018)

cambridge_tree_removal_years_df = cambridge_tree_df.loc[cambridge_tree_df['Removal_year'].isin(removal_years)]
cambridge_tree_removal_years_df.shape

# Now, look at month of removal
g = sns.factorplot(x="Removal_month", data=cambridge_tree_removal_years_df, kind="count", size=6, aspect=1.5)
g.set_xticklabels(step=1)
plt.xlabel('month tree removed')
plt.ylabel('Number of trees')

# %% [markdown]
# We see trees being removed across the year, with a small peak in October. This is to be expected.

# %%
# Lets plot this as a radial plot
print('total number of trees planted:', cambridge_tree_removal_years_df.Removal_month.count())
cambridge_tree_removal_years_df.Removal_month.value_counts()
# Out:
# total number of trees planted: 166
# 10    33
# 5     22
# 11    16
# 7     16
# 3     15
# 2     14
# 4     12
# 12    10
# 6      9
# 8      8
# 1      6
# 9      5
# Name: Removal_month, dtype: int64

# %%
num_trees_removed_per_month = [6, 14, 15, 12, 22, 9, 16, 8, 5, 33, 16, 10]

# divide by total num of trees planted to get proportions
prop_trees_removed_per_month = [x / 166 for x in num_trees_removed_per_month]
prop_trees_removed_per_month
# Out:
# [0.03614457831325301,
#  0.08433734939759036,
#  0.09036144578313253,
#  0.07228915662650602,
#  0.13253012048192772,
#  0.05421686746987952,
#  0.0963855421686747,
#  0.04819277108433735,
#  0.030120481927710843,
#  0.19879518072289157,
#  0.0963855421686747,
#  0.060240963855421686]

# %%
# Num of values (12 for months in year)
categories = ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
N = len(categories)

values = prop_trees_removed_per_month
values += values[:1]
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0.05,0.1,0.15,0.2], ["5%","10%","15%","20%"], color="grey", size=7)
plt.ylim(0,0.2)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'g', alpha=0.1)
plt.title('Month of tree removal')

# %% [markdown]
# ## Plot the location of the trees

# %%
# First I need to get the x and y coordinates of each tree (currently stored as a string)

# Get all positions
all_positions_list = cambridge_tree_df.the_geom.tolist()

# Initialize lists for x and y values
x_value_list = []
y_value_list = []

for i in all_positions_list:
    # A typical value will look something like this:
    # '{type=Point, coordinates=List(-71.11631432032273, 42.38359430732255)}'
    
    start = i.find('(')
    end = i.find(')')
    
    range_of_xy = i[start+1:end]
    
    comma = range_of_xy.find(',')
    space = range_of_xy.find(' ')
    
    # Get x and y
    x = range_of_xy[0:comma]
    y = range_of_xy[space+1:]
    
    # Add these values to list
    x_value_list.append(x)
    y_value_list.append(y)
    
cambridge_tree_df['longitude'] = x_value_list
cambridge_tree_df['latitude'] = y_value_list

cambridge_tree_df.head()
# Out:
#                                             the_geom  \
# 0  {type=Point, coordinates=List(-71.116314320322...
# 1  {type=Point, coordinates=List(-71.116463606176...
# 2  {type=Point, coordinates=List(-71.117121295780...
# 3  {type=Point, coordinates=List(-71.117457233419...
# 4  {type=Point, coordinates=List(-71.117663150576...
#
#                        modified  trunks                       created  \
# 0  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 1  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 2  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 3  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
# 4  08/12/2016 12:00:00 AM +0000       1  09/22/2005 12:00:00 AM +0000
#
#   SiteType  PlantDate RemovalDat   SpeciesSho TreeCondit  OverheadWi  \
# 0     Tree 1899-11-30 1899-11-30       Linden       Good           0
# 1     Tree 2012-05-31 1899-11-30        Maple       Fair           1
# ...

# %%
cambridge_tree_df.to_csv('updated_cambridge_tree_df.csv')

# %%
# import plotly.plotly as py

# data = [ dict(
#         type = 'scattergeo',
#         locationmode = 'USA-states',
#         lat = cambridge_tree_df['latitude'],
#         lon = cambridge_tree_df['longitude'],
#         text = cambridge_tree_df['SpeciesSho'],
#         mode = 'markers',
#         marker = dict(
#             size = 8,
#             opacity = 0.5,
#             reversescale = True,
#             autocolorscale = False,
#             symbol = 'circle',
#             line = dict(
#                 width=1,
#                 color='rgba(102, 102, 102)'
#             ),
#             colorscale = scl,
#             cmin = 0,
#             color = cambridge_tree_df['plant_year'],
#             cmax = cambridge_tree_df['plant_year'].max(),
#             colorbar=dict(
#                 title="Year planted"
#             )
#         ))]

# layout = dict(
#         title = 'Trees in Cambridge, MA<br>(Hover for species)',
#         colorbar = True,
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),
#             showland = True,
#             landcolor = "rgb(250, 250, 250)",
#             subunitcolor = "rgb(217, 217, 217)",
#             countrycolor = "rgb(217, 217, 217)",
#             countrywidth = 0.5,
#             subunitwidth = 0.5
#         ),
#     )

# fig = dict( data=data, layout=layout )
# py.iplot( fig, validate=False, filename='d3-airports' )

# %% [markdown]
# ### Fix typos

# %%
# Yep, they are lots of typos in the dataset, so lets clean these

for index, row in cambridge_tree_df.iterrows():
    sci_name = cambridge_tree_df.loc[index, "xCartegrap"]
    if sci_name == 'Cercis Canadensis':
        cambridge_tree_df.loc[index, "xCartegrap"] = 'Cercis canadensis'
        cambridge_tree_df.loc[index, "CommonName"] = 'redbud' 
    elif sci_name == 'platanus acerifolia':
        cambridge_tree_df.loc[index, "xCartegrap"] = 'Platanus acerifolia'
    elif sci_name == 'Liriodendron tulipifera':
        cambridge_tree_df.loc[index, "CommonName"] = 'tuliptree'
    elif sci_name == 'Ginkgo biloba':
        cambridge_tree_df.loc[index, "CommonName"] = 'Ginkgo'
    elif sci_name == 'Malus sp':
        cambridge_tree_df.loc[index, "CommonName"] = 'crabapple'
    elif sci_name == 'Betula nigra':
        cambridge_tree_df.loc[index, "CommonName"] = 'River Birch'
        
    other_sci_name = cambridge_tree_df.loc[index, "Scientific"]
    if other_sci_name == 'Cercis Canadensis':
        cambridge_tree_df.loc[index, "Scientific"] = 'Cercis canadensis'
        cambridge_tree_df.loc[index, "CommonName"] = 'redbud' 
    elif other_sci_name == 'platanus acerifolia':
        cambridge_tree_df.loc[index, "Scientific"] = 'Platanus x acerifolia'
        cambridge_tree_df.loc[index, "CommonName"] = 'London planetree' 
    elif other_sci_name == 'Maple sp.':
        cambridge_tree_df.loc[index, "Scientific"] = 'Pinus sp'    
    elif other_sci_name == 'Acer platanoides':
        cambridge_tree_df.loc[index, "CommonName"] = 'Norway Maple'   
    elif other_sci_name == 'Ostrya virginiana':
        cambridge_tree_df.loc[index, "CommonName"] = 'hophornbeam' 
    elif other_sci_name == 'Tilia cordata':
        cambridge_tree_df.loc[index, "CommonName"] = 'littleleaf linden'  
    elif other_sci_name == 'Tilia tomentosa':
        cambridge_tree_df.loc[index, "CommonName"] = 'silver linden' 
    elif other_sci_name == 'Eucommia ulmoides':
        cambridge_tree_df.loc[index, "CommonName"] = 'hardy rubber tree'    
    elif other_sci_name == 'Carpinus caroliniana':
        cambridge_tree_df.loc[index, "CommonName"] = 'American hornbeam' 
    elif other_sci_name == 'Gymnocladus dioicus':
        cambridge_tree_df.loc[index, "CommonName"] = 'Kentucky coffeetree' 
    elif other_sci_name == 'Quercus palustris':
        cambridge_tree_df.loc[index, "CommonName"] = 'pin oak'  
    elif other_sci_name == 'Platanus acerifolia':
        cambridge_tree_df.loc[index, "CommonName"] = 'London planetree' 
        cambridge_tree_df.loc[index, "Scientific"] = 'Platanus x acerifolia'
    elif other_sci_name == 'Betula papyrifera':
        cambridge_tree_df.loc[index, "CommonName"] = 'paper birch' 
    elif other_sci_name == 'Betula nigra':
        cambridge_tree_df.loc[index, "CommonName"] = 'River Birch'      
    elif other_sci_name == 'Malus sp':
        cambridge_tree_df.loc[index, "CommonName"] = 'crabapple' 
    elif other_sci_name == 'Cornus kousa':
        cambridge_tree_df.loc[index, "CommonName"] = 'Kousa dogwood' 
    elif other_sci_name == 'Acer rubrum':
        cambridge_tree_df.loc[index, "CommonName"] = 'Red Maple' 
    elif other_sci_name == 'Platanus occidentalis':
        cambridge_tree_df.loc[index, "CommonName"] = 'sycamore'    
    elif other_sci_name == 'Ulmus sp':
        cambridge_tree_df.loc[index, "CommonName"] = 'elm' 
    elif other_sci_name == 'Acer ginnala':
        cambridge_tree_df.loc[index, "CommonName"] = 'Amur maple' 
    elif other_sci_name == 'Pyrus calleryana':
        cambridge_tree_df.loc[index, "CommonName"] = 'Callery pear' 
    elif other_sci_name == 'Syringa reticulata':
        cambridge_tree_df.loc[index, "CommonName"] = 'Japanese tree lilac' 
    elif other_sci_name == 'Cercis canadensis':
        cambridge_tree_df.loc[index, "CommonName"] = 'redbud'     
    elif other_sci_name == 'Prunus subhirtella':
        cambridge_tree_df.loc[index, "CommonName"] = 'Autumnalis Higan cherry' 
    elif other_sci_name == 'Ginkgo biloba':
        cambridge_tree_df.loc[index, "CommonName"] = 'Ginkgo' 
    elif other_sci_name == 'Quercus bicolor':
        cambridge_tree_df.loc[index, "CommonName"] = 'swamp white oak' 
    elif other_sci_name == 'Ulmus americana':
        cambridge_tree_df.loc[index, "CommonName"] = 'American elm' 
    elif other_sci_name == 'Quercus rubra':
        cambridge_tree_df.loc[index, "CommonName"] = 'red oak' 
    elif other_sci_name == 'Koelreuteria paniculata':
        cambridge_tree_df.loc[index, "CommonName"] = 'golden raintree' 
    elif other_sci_name == 'Quercus robur':
        cambridge_tree_df.loc[index, "CommonName"] = 'English oak' 
    elif other_sci_name == 'Prunus serrulata':
        cambridge_tree_df.loc[index, "CommonName"] = 'Japanese flowering cherry' 
    elif other_sci_name == 'Celtis occidentalis':
        cambridge_tree_df.loc[index, "CommonName"] = 'hackberry' 
    elif other_sci_name == 'Pinus resinosa':
        cambridge_tree_df.loc[index, "CommonName"] = 'red pine' 
    elif other_sci_name == 'Nyssa sylvatica':
        cambridge_tree_df.loc[index, "CommonName"] = 'tupelo' 
    elif other_sci_name == 'Prunus × yedoensis':
        cambridge_tree_df.loc[index, "CommonName"] = 'Yoshino cherry' 
    elif other_sci_name == 'Gleditsia triacanthos':
        cambridge_tree_df.loc[index, "CommonName"] = 'honeylocust' 
    elif other_sci_name == 'Liriodendron tulipifera':
        cambridge_tree_df.loc[index, "CommonName"] = 'tuliptree' 
    elif other_sci_name == 'Amelanchier sp':
        cambridge_tree_df.loc[index, "CommonName"] = 'serviceberry' 
    elif other_sci_name == 'Acer campestre':
        cambridge_tree_df.loc[index, "CommonName"] = 'Hedge Maple' 
    elif other_sci_name == 'Cladrastis kentukea':
        cambridge_tree_df.loc[index, "CommonName"] = 'yellowwood' 
    elif other_sci_name == 'Magnolia sp':
        cambridge_tree_df.loc[index, "CommonName"] = 'magnolia' 
    elif other_sci_name == 'Maackia amurensis':
        cambridge_tree_df.loc[index, "CommonName"] = 'Maackia' 
    elif other_sci_name == 'Prunus sargentii':
        cambridge_tree_df.loc[index, "CommonName"] = 'Sargent cherry' 
    elif other_sci_name == 'Prunus x incamp':
        cambridge_tree_df.loc[index, "CommonName"] = 'Okame cherry' 
    elif other_sci_name == 'Liquidambar styraciflua':
        cambridge_tree_df.loc[index, "CommonName"] = 'sweetgum' 
    elif other_sci_name == 'Zelkova serrata':
        cambridge_tree_df.loc[index, "CommonName"] = 'Zelkova' 
    elif other_sci_name == 'Prunus sp':
        com_na = cambridge_tree_df.loc[index, "CommonName"]
        if com_na != 'apricot':
            if com_na != 'plum':
                cambridge_tree_df.loc[index, "CommonName"] = 'cherry'   
    elif other_sci_name == 'Tuliptree':
        cambridge_tree_df.loc[index, "Scientific"] = 'Liriodendron tulipifera' 
        cambridge_tree_df.loc[index, "CommonName"] = 'Tuliptree' 
    elif other_sci_name == 'Acer freemanii':
        cambridge_tree_df.loc[index, "CommonName"] = 'Freeman maple' 
    elif other_sci_name == 'Sophora japonica':
        cambridge_tree_df.loc[index, "CommonName"] = 'Japanese pagoda tree'  
        cambridge_tree_df.loc[index, "Scientific"] = 'Styphnolobium japonicum' 
    elif other_sci_name == 'Aesculus x carnea':
        cambridge_tree_df.loc[index, "CommonName"] = 'red horse chestnut'  
    elif other_sci_name == 'Planetree, London':
        cambridge_tree_df.loc[index, "Scientific"] = 'Platanus x acerifolia'
        cambridge_tree_df.loc[index, "CommonName"] = 'London Planetree'
    elif other_sci_name == 'Maackia':
        cambridge_tree_df.loc[index, "Scientific"] = 'Maackia amurensis'
        cambridge_tree_df.loc[index, "CommonName"] = 'Maackia'   
    elif other_sci_name == 'Amelanchier x grandiflora':
        cambridge_tree_df.loc[index, "CommonName"] = 'apple serviceberry'     
    elif other_sci_name == 'Acer platanoides L.':
        cambridge_tree_df.loc[index, "CommonName"] = 'Norway Maple'   
        cambridge_tree_df.loc[index, "Scientific"] = 'Acer platanoides' 
    elif other_sci_name == 'Serviceberry':
        cambridge_tree_df.loc[index, "CommonName"] = 'Serviceberry'   
        cambridge_tree_df.loc[index, "Scientific"] = 'Amelanchier sp' 
    elif other_sci_name == 'Quercus imbricaria':
        cambridge_tree_df.loc[index, "CommonName"] = 'shingle oak' 
    elif other_sci_name == 'Quercus imbricaria':
        cambridge_tree_df.loc[index, "CommonName"] = 'shingle oak'     
    elif other_sci_name == 'Ulmus japonica x wilsoniana':
        cambridge_tree_df.loc[index, "CommonName"] = 'Accolade Hybrid Elm'
    elif other_sci_name == 'Platanus acerifolia':
        cambridge_tree_df.loc[index, "Scientific"] = 'Platanus x acerifolia'    
        
        
        
        
    com_name = cambridge_tree_df.loc[index, "CommonName"]
    cambridge_tree_df.loc[index, "CommonName"] = str(com_name).title()
    if com_name == 'Arborvitae':
        cambridge_tree_df.loc[index, "CommonName"] = 'Eastern Arborvitae'
        
    # Changing all XX to XXX (most common ash)  -There are a number of trees that don't have species name
    elif com_name == 'Ash':
        cambridge_tree_df.loc[index, "CommonName"] = 'Green Ash'
        cambridge_tree_df.loc[index, "Species"] = 'Fraxinus pennsylvanica'
    elif com_name == 'Beech':
        cambridge_tree_df.loc[index, "CommonName"] = 'European Beech'
        cambridge_tree_df.loc[index, "Species"] = 'Fagus sylvatica'    
    elif com_name == 'Birch':
        cambridge_tree_df.loc[index, "CommonName"] = 'River Birch'
        cambridge_tree_df.loc[index, "Species"] = 'Betula nigra'

# %%
# # Plot scientific name of all trees
# cambridge_tree_df['xCartegrap'].value_counts().plot(kind='barh', figsize = (10, 25))
# plt.title('Frequency of tree types across all trees')

# %%
# # Plot common name of ALL trees
# cambridge_tree_df['CommonName'].value_counts().plot(kind='barh', figsize = (10, 25))
# plt.title('Frequency of tree types across all trees')

# %%
# Now, lets look at just living trees
living_trees_df = cambridge_tree_df[cambridge_tree_df['SiteType'] == 'Tree']
print('Number of living trees:', living_trees_df.shape[0])
living_trees_df['CommonName'].value_counts().plot(kind = 'barh', figsize = (10, 25))
plt.title('Frequency of tree types across all living trees (common name)')
# Out:
# Number of living trees: 29334

# %%
living_trees_df['Scientific'].value_counts().plot(kind = 'barh', figsize = (10, 25))
plt.title('Frequency of tree types across all living trees (scientific name)')

# %%
# Check that there are the same counts for common names and scientific names.
# Nope, they're not. :(
# print(len(living_trees_df['CommonName'].value_counts()))
# print(len(living_trees_df['xCartegrap'].value_counts()))
# print(len(living_trees_df['Scientific'].value_counts()))

# Fixed this - now they're good. : )

# %%
# len(new_sci_name_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-5d21e9263c5c> in <module>()
# ----> 1 len(new_sci_name_list)
#
# NameError: name 'new_sci_name_list' is not defined

# %%
# Looks like there are two columns with sci names. Which one is correct?

new_sci_name = list(set(living_trees_df['Scientific'].tolist()))
sci_name_list = list(set(living_trees_df.xCartegrap.tolist()))


main_list = np.setdiff1d(new_sci_name,sci_name_list)
main_list
# Out:
# array(['Acer freemanii', 'Aesculus x carnea', 'Amelanchier x grandiflora',
#        'Platanus x acerifolia', 'Quercus imbricaria',
#        'Ulmus japonica x wilsoniana'],
#       dtype='<U32')

# %%
new_sci_name_list = list(set(living_trees_df.Scientific.tolist()))
sci_name_list = list(set(living_trees_df.xCartegrap.tolist()))
com_name_list = list(set(living_trees_df.CommonName.tolist()))

# remove first value, which is nan
# new_sci_name_list.pop(0)
# sci_name_list.pop(0)
# com_name_list.pop(0)

# for name in new_sci_name_list:
#     this_name_df = living_trees_df[living_trees_df['Scientific'] == name]
#     this_scien_nam = list(set(this_name_df.xCartegrap.tolist()))
#     if len(this_scien_nam) > 1:
#         print(name)
#         print(this_scien_nam)
#         print('')
        
# print('now for the other')
        
# for name in sci_name_list:
#     this_name_df = living_trees_df[living_trees_df['xCartegrap'] == name]
#     this_scien_nam = list(set(this_name_df.Scientific.tolist()))
#     if len(this_scien_nam) > 1:
#         print(name)
#         print(this_scien_nam)
#         print('')





# for name in com_name_list:
#     this_name_df = living_trees_df[living_trees_df['CommonName'] == name]
#     this_scien_nam = list(set(this_name_df.xCartegrap.tolist()))
#     if len(this_scien_nam) > 1:
#         print(name)
#         print(this_scien_nam)
#         print('')
        
for name in new_sci_name_list:
    this_name_df = living_trees_df[living_trees_df['Scientific'] == name]
    this_com_nam = list(set(this_name_df.CommonName.tolist()))
#     if len(this_com_nam) == 0:
#         print(name)
    
    if len(this_com_nam) > 1:
        print(name)
        print(this_com_nam)
        print('')
        
print('xxx')
        
for name in com_name_list:
    this_name_df = living_trees_df[living_trees_df['CommonName'] == name]
    this_com_nam = list(set(this_name_df.Scientific.tolist()))
    if len(this_com_nam) == 0:
        print(name)
    
    if len(this_com_nam) > 1:
        print(name)
        print(this_com_nam)
        print('')
# Out:
# Prunus sp
# ['Cherry', 'Apricot', 'Plum']
#
# xxx

# %%
x = living_trees_df[living_trees_df['CommonName'] == 'Cherry']
this_com_nam = list(x.Scientific.tolist())
type_spec = set(this_com_nam)
print(len(this_com_nam))
type_spec
# Out:
# 511
# {'Prunus sp'}

# %% [markdown]
# Yep, there are typos. These are now fixed above. Also, xCartgraph has a lot of nan's, so stick to 'Scientific' column for data on scientific name

# %%
# Lets save the living tree df
living_trees_df.to_csv('living_trees_df.csv')

# %%
# Are there particular tree types that are removed?
removed_trees_df = cambridge_tree_df[cambridge_tree_df['SiteType'] == 'Retired']

# Plot common name of "retired trees
removed_trees_df['CommonName'].value_counts().plot(kind='barh')

# %% [markdown]
# We seem to have more norway and red maples removed than other trees. However, overall we have more of these trees than the others, so let's normalize these values such that we look at the percent of each tree type that's removed.
